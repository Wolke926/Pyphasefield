# %%
import sys
sys.path.append(r'C:\Users\futur\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines')
from MyDiffusionClass import MyDiffusionClass

sim = MyDiffusionClass(dimensions=[500, 500])

#initialize non-array parameters
sim.set_framework("CPU_SERIAL") #"CPU_SERIAL" (GPU_SERIAL not coded for MyDiffusionClass yet!)
sim.set_dx(1.)
sim.set_dt(0.1)
sim.set_save_path("data/diffusion_test")
sim.set_autosave_flag(True)
sim.set_autosave_save_images_flag(True)
sim.set_autosave_rate(2000)
sim.set_boundary_conditions("PERIODIC")

data = {
        "D":1.
}
sim.set_user_data(data)

#initialize simulation arrays, all parameter changes should be BEFORE this point!
sim.initialize_fields_and_imported_data()

#change array data here, for custom simulations
"""
sim.fields[0].data[:] = 1.
length = sim.dimensions[0]
width = sim.dimensions[1]
sim.fields[0].data[length // 4:3 * length // 4, width // 4:3 * width // 4] = 0.
"""


#initial conditions
sim.plot_simulation()

#run simulation
sim.simulate(2000)

#final conditions
sim.plot_simulation()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines\MyDiffusionClass.py:4
#       2 try:
#       3         #import from within Engines folder
# ----> 4         from ..field import Field
#       5         from ..simulation import Simulation
#
# ImportError: attempted relative import with no known parent package
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines\MyDiffusionClass.py:10
#       8 try:
#       9         #import classes from pyphasefield library
# ---> 10         from pyphasefield.field import Field
#      11         from pyphasefield.simulation import Simulation
#
# ModuleNotFoundError: No module named 'pyphasefield'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sys
#       2 sys.path.append(r'C:\Users\futur\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines')
# ----> 3 from MyDiffusionClass import MyDiffusionClass
#       5 sim = MyDiffusionClass(dimensions=[500, 500])
#       7 #initialize non-array parameters
#
# File ~\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines\MyDiffusionClass.py:14
#      12                 from pyphasefield.ppf_utils import COLORMAP_OTHER, COLORMAP_PHASE
#      13         except:
# ---> 14                 raise ImportError("Cannot import from pyphasefield library!")
#      16 class MyDiffusionClass(Simulation):
#      17         def __init__(self, **kwargs):
#
# ImportError: Cannot import from pyphasefield library!
