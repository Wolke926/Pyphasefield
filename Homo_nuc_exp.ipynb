# %%
import sys
sys.path.append(r'C:\Users\futur\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines')
from Homo_nucleation_1 import Homo_nucleation

def run_sim(x,time_steps,size):
    sim = Homo_nucleation(dimensions=[200, 200])

#initialize non-array parameters
    sim.set_framework("CPU_SERIAL")
    sim.set_dx(x)
    sim.set_dt(0.1)
    sim.set_time_step_counter(0)

    sim.set_autosave_flag(True)
    sim.set_autosave_save_images_flag(False)
    sim.set_autosave_rate(50)
    sim.set_boundary_conditions("PERIODIC")

    data = {
        "M":1.,
        "W":1.,
        "epsilon":1.,
        "r_star": 5.,
        "delta_f": 0.04714
    }
    data["r0"] = 1.1 * data["r_star"]

    sim.set_user_data(data)


#initialize simulation arrays, all parameter changes should be BEFORE this point!
    sim.initialize_fields_and_imported_data()

#change array data here, for custom simulations

#run simulation

    sim.plot_simulation()
    sim.simulate(200)
    sim.plot_simulation()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines\Homo_nucleation_1.py:5
#       3 try:
#       4         #import from within Engines folder
# ----> 5         from ..field import Field
#       6         from ..simulation import Simulation
#
# ImportError: attempted relative import with no known parent package
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines\Homo_nucleation_1.py:11
#       9 try:
#      10         #import classes from pyphasefield library
# ---> 11     from pyphasefield.field import Field
#      12     from pyphasefield.simulation import Simulation
#
# ModuleNotFoundError: No module named 'pyphasefield'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 import sys
#       2 sys.path.append(r'C:\Users\futur\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines')
# ----> 3 from Homo_nucleation_1 import Homo_nucleation
#       5 def run_sim(x,time_steps,size):
#       6     sim = Homo_nucleation(dimensions=[200, 200])
#
# File ~\anaconda3\envs\ppf\Lib\site-packages\pyphasefield\Engines\Homo_nucleation_1.py:15
#      13             from pyphasefield.ppf_utils import COLORMAP_OTHER, COLORMAP_PHASE
#      14         except:
# ---> 15             raise ImportError("Cannot import from pyphasefield library!")
#      17 def engine_CahnAllen(sim):
#      18     dt = sim.dt #SIM是被传进来的对象，其实叫什么都行，dt是属性
#
# ImportError: Cannot import from pyphasefield library!

# %%
sim = run_sim(0.1,500,200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sim = run_sim(0.1,500,200)
#
# NameError: name 'run_sim' is not defined
